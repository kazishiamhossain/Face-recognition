# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read image
img = cv2.imread('C:\\Users\\DCL\\Project\\Face recognition\\data\\male_000281.jpg')
# convert into gray scale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# apply haar cascade
haar = cv2.CascadeClassifier('./data/haarcascade_frontalface_default.xml')
faces = haar.detectMultiScale(gray, 1.3, 5)

# %%
print(faces)
# Out:
# [[ 316  453 1010 1010]]

# %%
plt.imshow(img)

# %%
cv2.rectangle(img,(316,453),(316+1010,453+1010),(0,255,0),3)
plt.imshow(img)

# %%
cv2.imshow('object_detect',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# crop
face_crop = img[416:616+1010,253:653+1010]
plt.imshow(face_crop)

# %%
cv2.imwrite('./data/male_01.png',face_crop)
# Out:
# True
